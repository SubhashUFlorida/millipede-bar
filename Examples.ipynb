# %% [markdown]
# # 1D model

# %% [markdown]
# ## Import libraries

# %%
import millipede_bar as mb

# %% [markdown]
# ## 1D model

# %%
df_exp = mb.get_incident_data(file="example.csv")
df_ana = mb.model_1d(df_incident=df_exp, parameter_file="parameters.toml")
df_ana.plot()
# Out:
# <AxesSubplot:>
